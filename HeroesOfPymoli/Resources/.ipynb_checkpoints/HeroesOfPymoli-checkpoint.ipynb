# %%
import pandas as pd
import numpy as np

# %%
file_to_load = "Resources/pymol_data.csv"

pymol_data = pd.read_csv("pymol_data.csv")
pymol_data.head()
# Out:
#    Purchase ID             SN  Age Gender  Item ID  \
# 0            0        Lisim78   20   Male      108
# 1            1    Lisovynya38   40   Male      143
# 2            2     Ithergue48   24   Male       92
# 3            3  Chamassasya86   24   Male      100
# 4            4      Iskosia90   23   Male      131
#
#                                    Item Name  Price
# 0  Extraction, Quickblade Of Trembling Hands   3.53
# 1                          Frenzied Scimitar   1.56
# 2                               Final Critic   4.88
# 3                                Blindscythe   3.27
# 4                                       Fury   1.44

# %%
# Player Count
total_players = pymol_data.SN.nunique()
total_players_df = pd.DataFrame({"Total Players": [total_players]})
total_players_df
# Out:
#    Total Players
# 0            576

# %%
# Purchase Analysis
uni_items = len(pymol_data["Item ID"].value_counts())
ave_price = pymol_data["Price"].mean()
purchase = pymol_data["Purchase ID"].count()
rev_total = pymol_data["Price"].sum()

summarydf = pd.DataFrame({"Number of Unique Items":[uni_items],
                          "Average Price":[ave_price],
                          "Number of Purchases":[purchase],
                          "Total Revenue":[rev_total]
                         })

# Formatting
summarydf.style.format({"Average Price":"${:.2f}", "Total Revenue": "${:,.2f}"})
# Out:
# <style type="text/css">
# </style>
# <table id="T_41f40_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Number of Unique Items</th>
#       <th class="col_heading level0 col1" >Average Price</th>
#       <th class="col_heading level0 col2" >Number of Purchases</th>
#       <th class="col_heading level0 col3" >Total Revenue</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_41f40_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_41f40_row0_col0" class="data row0 col0" >179</td>
#       <td id="T_41f40_row0_col1" class="data row0 col1" >$3.05</td>
#       <td id="T_41f40_row0_col2" class="data row0 col2" >780</td>
#       <td id="T_41f40_row0_col3" class="data row0 col3" >$2,379.77</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Gender Demographics 
gen_df = pymol_data[["SN", "Gender"]]
gen_df.shape
                     
gen_df = gen_df.drop_duplicates()
gen_df.shape
# Out:
# (576, 2)

# %%
gen_count = gen_df["Gender"].value_counts()
per_player = gen_count / total_players

# %%
demo = pd.DataFrame({"Total Number":gen_count,"Percentage of Players":per_player})
demo.style.format({"Percentage of Players":"{:.2%}"})
# Out:
# <style type="text/css">
# </style>
# <table id="T_770ce_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Total Number</th>
#       <th class="col_heading level0 col1" >Percentage of Players</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_770ce_level0_row0" class="row_heading level0 row0" >Male</th>
#       <td id="T_770ce_row0_col0" class="data row0 col0" >484</td>
#       <td id="T_770ce_row0_col1" class="data row0 col1" >84.03%</td>
#     </tr>
#     <tr>
#       <th id="T_770ce_level0_row1" class="row_heading level0 row1" >Female</th>
#       <td id="T_770ce_row1_col0" class="data row1 col0" >81</td>
#       <td id="T_770ce_row1_col1" class="data row1 col1" >14.06%</td>
#     </tr>
#     <tr>
#       <th id="T_770ce_level0_row2" class="row_heading level0 row2" >Other / Non-Disclosed</th>
#       <td id="T_770ce_row2_col0" class="data row2 col0" >11</td>
# ...

# %%
# Purchase Analysis / Gender
gender =pymol_data.groupby("Gender")

pur_count = gender["Purchase ID"].count()
pur_price = gender["Price"].mean()
value = gender["Price"].sum()
pur_per_person = value / gen_count

analysis = pd.DataFrame({"Purchase Count":pur_count, "Average Purchase Price":pur_price, "Total Purchase Value":value, "Avg Total Purchase per Person": pur_per_person})
analysis.style.format({"Average Purchase Price":"${:.2f}", "Total Purchase Value":"${:,.2f}", "Avg Total Purchase per Person":"${:.2f}"})
# Out:
# <style type="text/css">
# </style>
# <table id="T_2ebf2_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Purchase Count</th>
#       <th class="col_heading level0 col1" >Average Purchase Price</th>
#       <th class="col_heading level0 col2" >Total Purchase Value</th>
#       <th class="col_heading level0 col3" >Avg Total Purchase per Person</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2ebf2_level0_row0" class="row_heading level0 row0" >Female</th>
#       <td id="T_2ebf2_row0_col0" class="data row0 col0" >113</td>
#       <td id="T_2ebf2_row0_col1" class="data row0 col1" >$3.20</td>
#       <td id="T_2ebf2_row0_col2" class="data row0 col2" >$361.94</td>
#       <td id="T_2ebf2_row0_col3" class="data row0 col3" >$4.47</td>
#     </tr>
#     <tr>
#       <th id="T_2ebf2_level0_row1" class="row_heading level0 row1" >Male</th>
#       <td id="T_2ebf2_row1_col0" class="data row1 col0" >652</td>
# ...

# %%
# Age Demographics
group_age_data = pymol_data[["SN", "Age"]]
group_age_data = group_age_data.drop_duplicates()
group_age_data.shape

bins = [0, 9.9, 14.9, 19.9, 24.9, 29.9, 34.9, 39.9, 50]
bin_names = ["<10", "10-14", "15-19", "20-24", "25-29", "30-34", "35-39", "40+"]

# %%
group_age_data["Age Groups"] = pd.cut(group_age_data["Age"], bins, labels=bin_names)
group_age_data.head(10)

group_age_data = group_age_data.groupby("Age Groups")
total_count = group_age_data["Age"].count()
percentage = total_count / total_players

demo_age = pd.DataFrame({"Total Count":total_count, "Percentage of Players":percentage})
demo_age.style.format({"Percentage of Players":"{:.2%}"})
# Out:
# <style type="text/css">
# </style>
# <table id="T_2f3c0_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Total Count</th>
#       <th class="col_heading level0 col1" >Percentage of Players</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Age Groups</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2f3c0_level0_row0" class="row_heading level0 row0" ><10</th>
#       <td id="T_2f3c0_row0_col0" class="data row0 col0" >17</td>
#       <td id="T_2f3c0_row0_col1" class="data row0 col1" >2.95%</td>
#     </tr>
#     <tr>
#       <th id="T_2f3c0_level0_row1" class="row_heading level0 row1" >10-14</th>
#       <td id="T_2f3c0_row1_col0" class="data row1 col0" >22</td>
#       <td id="T_2f3c0_row1_col1" class="data row1 col1" >3.82%</td>
#     </tr>
#     <tr>
# ...

# %%
# Age - Purchasing Analsis

bins = [0, 9.9, 14.9, 19.9, 24.9, 29.9, 34.9, 39.9, 50]
bin_names = ["<10", "10-14", "15-19", "20-24", "25-29", "30-34", "35-39", "40+"]

pymol_data["Age Group"] = pd.cut(pymol_data["Age"], bins, labels=bin_names)
group_age = pymol_data.groupby("Age Group")
group_age.head()


purchase_count = group_age["Purchase ID"].count()
price = group_age["Price"].mean()
value = group_age["Price"].sum()
purchase = value / total_count

age_analysis = pd.DataFrame({"Purchase Count":purchase_count, "Average Purchase Price":price, "Total Purchase Value":value, "Avg Total Purchase per Person":purchase})
age_analysis.style.format({"Average Purchase Price":"${:,.2f}", "Total Purchase Value":"${:,.2f}", "Avg Total Purchase per Person":"${:,.2f}"})
# Out:
# <style type="text/css">
# </style>
# <table id="T_ec22c_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Purchase Count</th>
#       <th class="col_heading level0 col1" >Average Purchase Price</th>
#       <th class="col_heading level0 col2" >Total Purchase Value</th>
#       <th class="col_heading level0 col3" >Avg Total Purchase per Person</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Age Group</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ec22c_level0_row0" class="row_heading level0 row0" ><10</th>
#       <td id="T_ec22c_row0_col0" class="data row0 col0" >23</td>
#       <td id="T_ec22c_row0_col1" class="data row0 col1" >$3.35</td>
# ...

# %%
# Top Spenders

spend_df = pymol_data.groupby(["SN"])

purchase_count = spend_df["Purchase ID"].count()
price = spend_df["Price"].mean()
value = spend_df["Price"].sum()


top_spend_df = pd.DataFrame({"Purchase Count":purchase_count, "Average Purchase Price":price, "Total Purchase Value":value})

top_spend_df = top_spend_df.sort_values(["Total Purchase Value"], ascending=False)

top_spend_df["Average Purchase Price"] = top_spend_df["Average Purchase Price"].map("${:,.2f}".format)
top_spend_df["Total Purchase Value"] = top_spend_df["Total Purchase Value"].map("${:,.2f}".format)

top_spend_df[["Purchase Count", "Average Purchase Price", "Total Purchase Value"]].head()
# Out:
#              Purchase Count Average Purchase Price Total Purchase Value
# SN
# Lisosia93                 5                  $3.79               $18.96
# Idastidru52               4                  $3.86               $15.45
# Chamjask73                3                  $4.61               $13.83
# Iral74                    4                  $3.41               $13.62
# Iskadarya95               3                  $4.37               $13.10

# %%
# Most Popular Item

pop_items_df = pymol_data.groupby(["Item ID", "Item Name"])

purchase_count = pop_items_df["Purchase ID"].count()

pop_items_total = pop_items_df["Price"].sum()

pop_item_price = pop_items_total / purchase_count

items = pd.DataFrame({"Purchase Count":purchase_count, "Item Price": pop_item_price, "Total Purchase Value":pop_items_total})

item_summary = pop_items.sort_values(["Purchase Count"], ascending=False)

item_summary["Item Price"] = item_summary["Item Price"].map("${:,.2f}".format)
item_summary["Total Purchase Value"] = item_summary["Total Purchase Value"].map("${:,.2f}".format)


item_summary.head()
# Out:
#                                                       Purchase Count  \
# Item ID Item Name
# 92      Final Critic                                              13
# 178     Oathbreaker, Last Hope of the Breaking Storm              12
# 145     Fiery Glass Crusader                                       9
# 132     Persuasion                                                 9
# 108     Extraction, Quickblade Of Trembling Hands                  9
#
#                                                      Item Price  \
# Item ID Item Name
# 92      Final Critic                                      $4.61
# 178     Oathbreaker, Last Hope of the Breaking Storm      $4.23
# 145     Fiery Glass Crusader                              $4.58
# 132     Persuasion                                        $3.22
# 108     Extraction, Quickblade Of Trembling Hands         $3.53
#
#                                                      Total Purchase Value
# Item ID Item Name
# ...

# %%
# Most Profitable

profit_items = items.sort_values(["Total Purchase Value"], ascending = False)

profit_items.head()
# Out:
#                                                       Purchase Count  \
# Item ID Item Name
# 92      Final Critic                                              13
# 178     Oathbreaker, Last Hope of the Breaking Storm              12
# 82      Nirvana                                                    9
# 145     Fiery Glass Crusader                                       9
# 103     Singed Scalpel                                             8
#
#                                                       Item Price  \
# Item ID Item Name
# 92      Final Critic                                    4.614615
# 178     Oathbreaker, Last Hope of the Breaking Storm    4.230000
# 82      Nirvana                                         4.900000
# 145     Fiery Glass Crusader                            4.580000
# 103     Singed Scalpel                                  4.350000
#
#                                                       Total Purchase Value
# Item ID Item Name
# ...
